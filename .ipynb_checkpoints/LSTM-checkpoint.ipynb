# %% [markdown]
# # LSTM預測

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("bmh")
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %% [markdown]
# ## 建立函數

# %% [markdown]
# ### 獲取資料

# %%
def getData(symbol):
    data_name = pd.read_csv('./ListedCompany.csv', index_col='代號')
    name = data_name.loc[symbol]['名稱']
    
    data = pd.read_csv(f'./data/{symbol}.csv')   
    data['date'] = pd.to_datetime(data['date'])
    data = data.set_index('date')
    data = data.drop('change', axis=1)
#     data.trade_volume = data.trade_volume.astype('int').copy()
#     data.trade_value = data.trade_value.astype('int').copy()
#     data.opening_price = data.opening_price.astype('float').copy()
#     data.highest_price = data.highest_price.astype('float').copy()
#     data.lowest_price = data.lowest_price.astype('float').copy()
#     data.closing_price = data.closing_price.astype('float').copy()
#     data.transaction = data.transaction.astype('int').copy()

    return name, data

# %% [markdown]
# ### 趨勢圖

# %%
def plotClosePrice(name, df):
    plt.figure(figsize=(16,8))
    plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta']
    plt.title(f'{name}歷史收盤價', fontsize=14)
    plt.plot(df['closing_price'])
    plt.xlabel('日期', fontsize=12)
    plt.ylabel('收盤價', fontsize=12)

# %%
symbol = 2454
# 取得資料
name, data = getData(symbol)
# 繪製歷年走勢
plotClosePrice(name, data)

# %% [markdown]
# ### 拆分 X, y

# %%
def buildXY(data, p, f):
    x_data, y_data = [], []
    for i in range(data.shape[0]-f-p+1):
        x_data.append(np.array(data[i: i+p]))
        y_data.append(np.array(data[i+p: i+p+f][:, 5]))
    return np.array(x_data), np.array(y_data)

# %% [markdown]
# ### 調整維度

# %%
def reshapeData(x, y, variable):
    y_data = np.reshape(y, (y.shape[0], y.shape[1], 1))
    if variable == 1:
        x = x[:,:,5]
        x_data = np.reshape(x, (x.shape[0], x.shape[1], 1))
    else:
        x_data = x
    return x_data, y_data

# %% [markdown]
# ### 洗亂訓練資料集

# %%
def shuffle(x, y):
    np.random.seed(0)
    randomList = np.arange(x.shape[0])
    np.random.shuffle(randomList)
    return x[randomList], y[randomList]

# %% [markdown]
# ### 建立模型

# %%
def manyToOne(x_train, neurons, d):
    model = Sequential()
    model.add(LSTM(neurons[0], return_sequences=True, input_shape= (x_train.shape[1], x_train.shape[2])))
    model.add(Dropout(d))
    model.add(LSTM(neurons[1], return_sequences= False))
    model.add(Dropout(d))
    model.add(Dense(neurons[2]))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.summary()
    return model

# %% [markdown]
# ### 模型評估標準

# %%
def modelScore(model, x_train, y_train, x_test, y_test):
    train_score = model.evaluate(x_train, y_train)
    test_score = model.evaluate(x_test, y_test)
    print(f"Train Score: {train_score:.5f} MSE ({np.sqrt(train_score):.3f} RMSE)")
    print(f"Test Score: {test_score:.5f} MSE ({np.sqrt(test_score):.3f} RMSE)")
    return train_score, test_score

# %% [markdown]
# ### 模型預測圖

# %%
def plotModel(name, data, predictions_price):
    train = data['closing_price'][:-predictions_price.shape[0]].to_frame()
    test = data['closing_price'][-predictions_price.shape[0]:].to_frame()
    rmse = np.sqrt(mean_squared_error(predictions_price, test.values))
    test['Predictions'] = predictions_price
    plt.figure(figsize=(12,6))
    plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta']
    plt.title(f'RMSE: {rmse:.3f}', fontsize=14, color='firebrick')
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Closing Price', fontsize=12)
    plt.plot(train)
    plt.plot(test['closing_price'], 'darkorange', test['Predictions'], 'firebrick')
    plt.legend(['Train', 'Test', 'Predictions'], loc='lower right')
    print(f"RMSE: {rmse:.3f}")
    return rmse

# %% [markdown]
# ## LSTM

# %%
futureDay = 1    # 預測未來天數
pastDay = 5    #過去幾天
variable = 2    # variable一個或多個
neurons = [64, 64, 32]
d = .2    # dropout
rate = .8    # train rate
batch_size = 32
epochs = 100
validation_split = .1

train_data, test_data = data[:int(data.shape[0]*0.8)], data[int(data.shape[0]*0.8):]

# 歸一化
scaler = MinMaxScaler(feature_range = (0, 1))
scaler = scaler.fit(train_data.values)
scaled_train_data = scaler.transform(train_data.values)
scaled_test_data = scaler.transform(test_data.values)

x_train, y_train = buildXY(scaled_train_data, pastDay, futureDay)
x_test, y_test = buildXY(scaled_test_data, pastDay, futureDay)

x_train, y_train = reshapeData(x_train, y_train, variable)
x_test, y_test = reshapeData(x_test, y_test, variable)

x_train, y_train = shuffle(x_train, y_train)

# %%
# LSTM模型
model = manyToOne(x_train, neurons, d)
# fit model
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_split = validation_split)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 64)             18432
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 53,569
# Trainable params: 53,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 56/56 [==============================] - 4s 25ms/step - loss: 0.0508 - val_loss: 0.0015
# Epoch 2/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 3/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 4/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 5/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 6/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 7/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 8/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 9/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 10/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 11/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 12/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 13/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 14/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 9.5356e-04
# Epoch 15/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 16/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 17/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 9.2637e-04
# Epoch 18/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 19/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 20/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 8.9126e-04
# Epoch 21/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 22/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 23/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 8.9277e-04
# Epoch 24/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 8.3118e-04
# Epoch 25/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 7.9691e-04
# Epoch 26/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 7.6383e-04
# Epoch 27/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 7.3576e-04
# Epoch 28/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 8.8945e-04
# Epoch 29/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0013 - val_loss: 7.0607e-04
# Epoch 30/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 6.8993e-04
# Epoch 31/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 7.2496e-04
# Epoch 32/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 7.7127e-04
# Epoch 33/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 8.8189e-04
# Epoch 34/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 7.7840e-04
# Epoch 35/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 7.8197e-04
# Epoch 36/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 6.5858e-04
# Epoch 37/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 38/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 5.8058e-04
# Epoch 39/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 8.5526e-04
# Epoch 40/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 5.8260e-04
# Epoch 41/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 6.5702e-04
# Epoch 42/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 5.1313e-04
# Epoch 43/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 5.1630e-04
# Epoch 44/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.9318e-04 - val_loss: 5.1250e-04
# Epoch 45/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6264e-04 - val_loss: 7.4219e-04
# Epoch 46/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 5.0957e-04
# Epoch 47/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 7.7507e-04
# Epoch 48/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 5.5979e-04
# Epoch 49/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 5.2483e-04
# Epoch 50/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 4.4076e-04
# Epoch 51/100
# 56/56 [==============================] - 0s 7ms/step - loss: 9.7922e-04 - val_loss: 7.7260e-04
# Epoch 52/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 4.9447e-04
# Epoch 53/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6269e-04 - val_loss: 4.3102e-04
# Epoch 54/100
# 56/56 [==============================] - 0s 7ms/step - loss: 9.5846e-04 - val_loss: 0.0013
# Epoch 55/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 4.5346e-04
# Epoch 56/100
# 56/56 [==============================] - 0s 7ms/step - loss: 9.9044e-04 - val_loss: 5.3770e-04
# Epoch 57/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 4.1532e-04
# Epoch 58/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.2928e-04 - val_loss: 4.7478e-04
# Epoch 59/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 4.7353e-04
# Epoch 60/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 4.0955e-04
# Epoch 61/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.0783e-04 - val_loss: 3.9559e-04
# Epoch 62/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 6.8932e-04
# Epoch 63/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 64/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 3.9217e-04
# Epoch 65/100
# 56/56 [==============================] - 1s 12ms/step - loss: 8.7067e-04 - val_loss: 4.4181e-04
# Epoch 66/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 5.7769e-04
# Epoch 67/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 4.0149e-04
# Epoch 68/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 4.0311e-04
# Epoch 69/100
# 56/56 [==============================] - 0s 7ms/step - loss: 9.1484e-04 - val_loss: 4.1736e-04
# Epoch 70/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.3984e-04 - val_loss: 4.1104e-04
# Epoch 71/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 5.4625e-04
# Epoch 72/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.7470e-04 - val_loss: 5.4565e-04
# Epoch 73/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.8548e-04 - val_loss: 3.7082e-04
# Epoch 74/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.8008e-04 - val_loss: 3.5684e-04
# Epoch 75/100
# 56/56 [==============================] - 0s 7ms/step - loss: 8.9087e-04 - val_loss: 4.0368e-04
# Epoch 76/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.8509e-04 - val_loss: 4.6215e-04
# Epoch 77/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.3260e-04 - val_loss: 5.5590e-04
# Epoch 78/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.9791e-04 - val_loss: 4.3910e-04
# Epoch 79/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.6319e-04 - val_loss: 3.5843e-04
# Epoch 80/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.2798e-04 - val_loss: 6.4608e-04
# Epoch 81/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.7055e-04 - val_loss: 3.9113e-04
# Epoch 82/100
# 56/56 [==============================] - 0s 8ms/step - loss: 8.9862e-04 - val_loss: 3.6713e-04
# Epoch 83/100
# 56/56 [==============================] - 1s 9ms/step - loss: 8.6017e-04 - val_loss: 4.2227e-04
# Epoch 84/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.3897e-04 - val_loss: 4.0576e-04
# Epoch 85/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.0786e-04 - val_loss: 4.1195e-04
# Epoch 86/100
# 56/56 [==============================] - 1s 9ms/step - loss: 8.2540e-04 - val_loss: 3.4152e-04
# Epoch 87/100
# 56/56 [==============================] - 1s 9ms/step - loss: 7.9895e-04 - val_loss: 3.6468e-04
# Epoch 88/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.1682e-04 - val_loss: 4.7018e-04
# Epoch 89/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.4490e-04 - val_loss: 9.5094e-04
# Epoch 90/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0010 - val_loss: 3.7383e-04
# Epoch 91/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.1258e-04 - val_loss: 0.0010
# Epoch 92/100
# 56/56 [==============================] - 0s 9ms/step - loss: 9.8028e-04 - val_loss: 4.3353e-04
# Epoch 93/100
# 56/56 [==============================] - 1s 12ms/step - loss: 9.1650e-04 - val_loss: 3.9443e-04
# Epoch 94/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.5169e-04 - val_loss: 6.5682e-04
# Epoch 95/100
# 56/56 [==============================] - 1s 11ms/step - loss: 8.9044e-04 - val_loss: 3.3510e-04
# Epoch 96/100
# 56/56 [==============================] - 1s 12ms/step - loss: 8.6137e-04 - val_loss: 4.0527e-04
# Epoch 97/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.1868e-04 - val_loss: 3.5228e-04
# Epoch 98/100
# 56/56 [==============================] - 1s 10ms/step - loss: 8.3540e-04 - val_loss: 3.7522e-04
# Epoch 99/100
# 56/56 [==============================] - 1s 11ms/step - loss: 8.5974e-04 - val_loss: 3.4396e-04
# Epoch 100/100
# 56/56 [==============================] - 1s 12ms/step - loss: 9.0364e-04 - val_loss: 5.5528e-04

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title('Loss', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Loss')

# %% [markdown]
# ### 模型分數

# %%
train_score, test_score = modelScore(model, x_train, y_train, x_test, y_test)
# Out:
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7551e-04
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0051
# Train Score: 0.00068 MSE (0.026 RMSE)
# Test Score: 0.00508 MSE (0.071 RMSE)

# %% [markdown]
# ### 預測圖

# %%
# 預測
predictions = model.predict(x_test)
# inverse
scaler = MinMaxScaler(feature_range = (0, 1))
scaler = scaler.fit(train_data.iloc[:, 5].values.reshape(-1, 1))
predictions_price = scaler.inverse_transform(predictions)

# 繪製預測走勢圖，計算rmse
rmse_price = plotModel(name, data, predictions_price)
# Out:
# RMSE: 24.449

# %% [markdown]
# ## 優化參數

# %% [markdown]
# ### 建立函數

# %%
def LSTMClosingPrice(data, futureDay, pastDay, variable, neurons, d):
    rate = .8
    batch_size = 32
    epochs = 100
    validation_split = .1

    train_data, test_data = data[:int(data.shape[0]*0.8)], data[int(data.shape[0]*0.8):]

    scaler = MinMaxScaler(feature_range = (0, 1))
    scaler = scaler.fit(train_data.values)
    scaled_train_data = scaler.transform(train_data.values)
    scaled_test_data = scaler.transform(test_data.values)

    x_train, y_train = buildXY(scaled_train_data, pastDay, futureDay)
    x_test, y_test = buildXY(scaled_test_data, pastDay, futureDay)

    x_train, y_train = reshapeData(x_train, y_train, variable)
    x_test, y_test = reshapeData(x_test, y_test, variable)

    x_train, y_train = shuffle(x_train, y_train)

    # LSTM模型
    model = manyToOne(x_train, neurons, d)
    # fit model
    history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_split = validation_split, verbose = 0)

    # print 模型分數
    train_score, test_score = modelScore(model, x_train, y_train, x_test, y_test)

    # 預測
    predictions = model.predict(x_test)
    # inverse
    scaler = MinMaxScaler(feature_range = (0, 1))
    scaler = scaler.fit(train_data.iloc[:, 5].values.reshape(-1, 1))
    predictions_price = scaler.inverse_transform(predictions)

    test = data['closing_price'][-predictions_price.shape[0]:].to_frame()
    rmse = np.sqrt(mean_squared_error(predictions_price, test.values))
    return rmse

# %% [markdown]
# ### 變數數量

# %%
symbol = 2454
name, data = getData(symbol)
futureDay = 1
neurons = [64, 64, 32]
d = .2 
pastDay_list = 5

# 收盤價預測收盤價
rmse_price_1 = LSTMClosingPrice(data, futureDay, pastDay, 1, neurons, d)

# 所有變數預測收盤價
rmse_price_2 = LSTMClosingPrice(data, futureDay, pastDay, 2, neurons, d)

print('')
print(f'rmse_price_1: {rmse_price_1}')
print(f'rmse_price_2: {rmse_price_2}')
# Out:
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_92 (LSTM)               (None, 5, 64)             16896
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 5, 64)             0
# _________________________________________________________________
# lstm_93 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_93 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 3ms/step - loss: 4.3751e-04
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015
# Train Score: 0.00044 MSE (0.021 RMSE)
# Test Score: 0.00148 MSE (0.039 RMSE)
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_94 (LSTM)               (None, 5, 64)             18432
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 5, 64)             0
# _________________________________________________________________
# lstm_95 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_94 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 53,569
# Trainable params: 53,569
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 3ms/step - loss: 4.6598e-04
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0040
# Train Score: 0.00047 MSE (0.022 RMSE)
# Test Score: 0.00398 MSE (0.063 RMSE)
#
# rmse_price_1: 13.21171133279384
# rmse_price_2: 21.65193683306732

# %% [markdown]
# ### Past Day

# %%
symbol = 2454
name, data = getData(symbol)

futureDay = 1
variable = 1
neurons = [64, 64, 32]
d = .2 
pastDay_list = [5, 10, 20, 60, 120]
pastDay_result = []
for pastDay in pastDay_list:    
    rmse_price = LSTMClosingPrice(data, futureDay, pastDay, variable, neurons, d)
    pastDay_result.append(rmse_price)
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_96 (LSTM)               (None, 5, 64)             16896
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 5, 64)             0
# _________________________________________________________________
# lstm_97 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_96 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_97 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 3ms/step - loss: 4.7106e-04
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0018
# Train Score: 0.00047 MSE (0.022 RMSE)
# Test Score: 0.00183 MSE (0.043 RMSE)
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_98 (LSTM)               (None, 10, 64)            16896
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 10, 64)            0
# _________________________________________________________________
# lstm_99 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_98 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 5ms/step - loss: 4.2856e-04
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0013
# Train Score: 0.00043 MSE (0.021 RMSE)
# Test Score: 0.00125 MSE (0.035 RMSE)
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_100 (LSTM)              (None, 20, 64)            16896
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 20, 64)            0
# _________________________________________________________________
# lstm_101 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_100 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_101 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 61/61 [==============================] - 0s 8ms/step - loss: 4.0860e-04
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Train Score: 0.00041 MSE (0.020 RMSE)
# Test Score: 0.00135 MSE (0.037 RMSE)
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_102 (LSTM)              (None, 60, 64)            16896
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 60, 64)            0
# _________________________________________________________________
# lstm_103 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_103 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 60/60 [==============================] - 2s 26ms/step - loss: 4.0559e-04: 0s - loss: 4.0322e-0
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0016
# Train Score: 0.00041 MSE (0.020 RMSE)
# Test Score: 0.00156 MSE (0.039 RMSE)
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_104 (LSTM)              (None, 120, 64)           16896
# _________________________________________________________________
# dropout_104 (Dropout)        (None, 120, 64)           0
# _________________________________________________________________
# lstm_105 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 58/58 [==============================] - 3s 48ms/step - loss: 5.1778e-04
# 12/12 [==============================] - 1s 49ms/step - loss: 0.0023
# Train Score: 0.00052 MSE (0.023 RMSE)
# Test Score: 0.00232 MSE (0.048 RMSE)

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(pastDay_list)), pastDay_result, '-o')
plt.xticks(range(len(pastDay_list)), pastDay_list)
plt.xlabel('Past Days', fontsize=14)
plt.ylabel('Mean Square Error', fontsize=14)
# plt.annotate('minimum', xy=(0, 0.0002), xytext=(0.5, 0.0007), arrowprops=dict(facecolor='black', shrink=0.05), fontsize=16)
pastDay_np = np.array([pastDay_list, pastDay_result])
np.save('pastDay.npy',pastDay_np)

# %% [markdown]
# ### Dropout

# %%
symbol = 2454
name, data = getData(symbol)

futureDay = 1
pastDay = 10
variable = 1
neurons = [128, 128, 32]
dropout_list = [.2, .3, .4, .5, .6, .7, .8]
dropout_result = []
for d in dropout_list:    
    rmse_price = LSTMClosingPrice(data, futureDay, pastDay, variable, neurons, d)
    dropout_result.append(rmse_price)
# Out:
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_150 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_150 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_151 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_151 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_150 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_151 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 12ms/step - loss: 4.0309e-04
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0013
# Train Score: 0.00040 MSE (0.020 RMSE)
# Test Score: 0.00127 MSE (0.036 RMSE)
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_152 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_152 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_153 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_153 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_152 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_153 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 12ms/step - loss: 5.5453e-04
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0025
# Train Score: 0.00055 MSE (0.024 RMSE)
# Test Score: 0.00251 MSE (0.050 RMSE)
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_154 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_154 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_155 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_155 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_154 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_155 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 11ms/step - loss: 8.3535e-04
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0053
# Train Score: 0.00084 MSE (0.029 RMSE)
# Test Score: 0.00529 MSE (0.073 RMSE)
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_156 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_156 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_157 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_157 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_156 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_157 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 11ms/step - loss: 7.6327e-04
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0019
# Train Score: 0.00076 MSE (0.028 RMSE)
# Test Score: 0.00190 MSE (0.044 RMSE)
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_158 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_158 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_159 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_159 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_158 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_159 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 12ms/step - loss: 7.5960e-04
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0018
# Train Score: 0.00076 MSE (0.028 RMSE)
# Test Score: 0.00181 MSE (0.043 RMSE)
# Model: "sequential_80"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_160 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_160 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_161 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_161 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_160 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_161 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 14ms/step - loss: 8.0975e-04
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0063
# Train Score: 0.00081 MSE (0.028 RMSE)
# Test Score: 0.00631 MSE (0.079 RMSE)
# Model: "sequential_81"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_162 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_162 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_163 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_163 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_162 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_163 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 12ms/step - loss: 9.3634e-04
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0052
# Train Score: 0.00094 MSE (0.031 RMSE)
# Test Score: 0.00517 MSE (0.072 RMSE)

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(dropout_list)), dropout_result, '-o')
plt.xticks(range(len(dropout_list)), dropout_list)
plt.xlabel('Dropout', fontsize=14)
plt.ylabel('Mean Square Error', fontsize=14)
# plt.annotate('minimum', xy=(0, 0.0002), xytext=(1.5, 0.0025), arrowprops=dict(facecolor='black', shrink=0.05), fontsize=16)
dropout_np = np.array([dropout_list, dropout_result])
np.save('dropout.npy',dropout_np)

# %% [markdown]
# ### Neurons

# %%
symbol = 2454
name, data = getData(symbol)

futureDay = 1
pastDay = 10
variable = 1
d = .2
neurons_LSTM = [32, 64, 128, 256, 512]
neurons_Dense = [16, 32, 64]
neurons_L = []
neurons_D = []
neurons_result = []
for i in neurons_LSTM:
    for j in neurons_Dense:
        neurons = [i, i, j]
        rmse_price = LSTMClosingPrice(data, futureDay, pastDay, variable, neurons, d)
        neurons_result.append(rmse_price)
        neurons_L.append(i)
        neurons_D.append(j)
# Out:
# Model: "sequential_82"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_164 (LSTM)              (None, 10, 32)            4352
# _________________________________________________________________
# dropout_164 (Dropout)        (None, 10, 32)            0
# _________________________________________________________________
# lstm_165 (LSTM)              (None, 32)                8320
# _________________________________________________________________
# dropout_165 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_164 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_165 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 13,217
# Trainable params: 13,217
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 4ms/step - loss: 5.0723e-04
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0014
# Train Score: 0.00051 MSE (0.023 RMSE)
# Test Score: 0.00141 MSE (0.038 RMSE)
# Model: "sequential_83"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_166 (LSTM)              (None, 10, 32)            4352
# _________________________________________________________________
# dropout_166 (Dropout)        (None, 10, 32)            0
# _________________________________________________________________
# lstm_167 (LSTM)              (None, 32)                8320
# _________________________________________________________________
# dropout_167 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_166 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_167 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 13,761
# Trainable params: 13,761
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 3ms/step - loss: 4.3613e-04
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015
# Train Score: 0.00044 MSE (0.021 RMSE)
# Test Score: 0.00152 MSE (0.039 RMSE)
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_168 (LSTM)              (None, 10, 32)            4352
# _________________________________________________________________
# dropout_168 (Dropout)        (None, 10, 32)            0
# _________________________________________________________________
# lstm_169 (LSTM)              (None, 32)                8320
# _________________________________________________________________
# dropout_169 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_168 (Dense)            (None, 64)                2112
# _________________________________________________________________
# dense_169 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 14,849
# Trainable params: 14,849
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 3ms/step - loss: 4.7312e-04
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016
# Train Score: 0.00047 MSE (0.022 RMSE)
# Test Score: 0.00163 MSE (0.040 RMSE)
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_170 (LSTM)              (None, 10, 64)            16896
# _________________________________________________________________
# dropout_170 (Dropout)        (None, 10, 64)            0
# _________________________________________________________________
# lstm_171 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_171 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_170 (Dense)            (None, 16)                1040
# _________________________________________________________________
# dense_171 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 50,977
# Trainable params: 50,977
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 5ms/step - loss: 4.2167e-04
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0013
# Train Score: 0.00042 MSE (0.021 RMSE)
# Test Score: 0.00128 MSE (0.036 RMSE)
# Model: "sequential_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_172 (LSTM)              (None, 10, 64)            16896
# _________________________________________________________________
# dropout_172 (Dropout)        (None, 10, 64)            0
# _________________________________________________________________
# lstm_173 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_173 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_172 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_173 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 52,033
# Trainable params: 52,033
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 4ms/step - loss: 4.1121e-04
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0014
# Train Score: 0.00041 MSE (0.020 RMSE)
# Test Score: 0.00142 MSE (0.038 RMSE)
# Model: "sequential_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_174 (LSTM)              (None, 10, 64)            16896
# _________________________________________________________________
# dropout_174 (Dropout)        (None, 10, 64)            0
# _________________________________________________________________
# lstm_175 (LSTM)              (None, 64)                33024
# _________________________________________________________________
# dropout_175 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_174 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_175 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 54,145
# Trainable params: 54,145
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 0s 5ms/step - loss: 4.1894e-04
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0015
# Train Score: 0.00042 MSE (0.020 RMSE)
# Test Score: 0.00147 MSE (0.038 RMSE)
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_176 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_176 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_177 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_177 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_176 (Dense)            (None, 16)                2064
# _________________________________________________________________
# dense_177 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 200,225
# Trainable params: 200,225
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 11ms/step - loss: 4.6165e-04
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0018
# Train Score: 0.00046 MSE (0.021 RMSE)
# Test Score: 0.00177 MSE (0.042 RMSE)
# Model: "sequential_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_178 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_178 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_179 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_179 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_178 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_179 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 202,305
# Trainable params: 202,305
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 11ms/step - loss: 5.3232e-04
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0018
# Train Score: 0.00053 MSE (0.023 RMSE)
# Test Score: 0.00178 MSE (0.042 RMSE)
# Model: "sequential_90"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_180 (LSTM)              (None, 10, 128)           66560
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_181 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_180 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_181 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 206,465
# Trainable params: 206,465
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 1s 19ms/step - loss: 4.3836e-04
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0014
# Train Score: 0.00044 MSE (0.021 RMSE)
# Test Score: 0.00142 MSE (0.038 RMSE)
# Model: "sequential_91"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_182 (LSTM)              (None, 10, 256)           264192
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 10, 256)           0
# _________________________________________________________________
# lstm_183 (LSTM)              (None, 256)               525312
# _________________________________________________________________
# dropout_183 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_182 (Dense)            (None, 16)                4112
# _________________________________________________________________
# dense_183 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 793,633
# Trainable params: 793,633
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 2s 35ms/step - loss: 4.6070e-04
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0012
# Train Score: 0.00046 MSE (0.021 RMSE)
# Test Score: 0.00122 MSE (0.035 RMSE)
# Model: "sequential_92"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_184 (LSTM)              (None, 10, 256)           264192
# _________________________________________________________________
# dropout_184 (Dropout)        (None, 10, 256)           0
# _________________________________________________________________
# lstm_185 (LSTM)              (None, 256)               525312
# _________________________________________________________________
# dropout_185 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_184 (Dense)            (None, 32)                8224
# _________________________________________________________________
# dense_185 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 797,761
# Trainable params: 797,761
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 2s 32ms/step - loss: 4.2030e-04
# 16/16 [==============================] - 1s 30ms/step - loss: 0.0013
# Train Score: 0.00042 MSE (0.021 RMSE)
# Test Score: 0.00129 MSE (0.036 RMSE)
# Model: "sequential_93"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_186 (LSTM)              (None, 10, 256)           264192
# _________________________________________________________________
# dropout_186 (Dropout)        (None, 10, 256)           0
# _________________________________________________________________
# lstm_187 (LSTM)              (None, 256)               525312
# _________________________________________________________________
# dropout_187 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_186 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dense_187 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 806,017
# Trainable params: 806,017
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 2s 32ms/step - loss: 6.3815e-04
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0025
# Train Score: 0.00064 MSE (0.025 RMSE)
# Test Score: 0.00247 MSE (0.050 RMSE)
# Model: "sequential_94"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_188 (LSTM)              (None, 10, 512)           1052672
# _________________________________________________________________
# dropout_188 (Dropout)        (None, 10, 512)           0
# _________________________________________________________________
# lstm_189 (LSTM)              (None, 512)               2099200
# _________________________________________________________________
# dropout_189 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_188 (Dense)            (None, 16)                8208
# _________________________________________________________________
# dense_189 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 3,160,097
# Trainable params: 3,160,097
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 7s 105ms/step - loss: 5.1365e-04
# 16/16 [==============================] - 2s 99ms/step - loss: 0.0017
# Train Score: 0.00051 MSE (0.023 RMSE)
# Test Score: 0.00166 MSE (0.041 RMSE)
# Model: "sequential_95"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_190 (LSTM)              (None, 10, 512)           1052672
# _________________________________________________________________
# dropout_190 (Dropout)        (None, 10, 512)           0
# _________________________________________________________________
# lstm_191 (LSTM)              (None, 512)               2099200
# _________________________________________________________________
# dropout_191 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_190 (Dense)            (None, 32)                16416
# _________________________________________________________________
# dense_191 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 3,168,321
# Trainable params: 3,168,321
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 7s 109ms/step - loss: 4.3093e-04
# 16/16 [==============================] - 2s 108ms/step - loss: 0.0012
# Train Score: 0.00043 MSE (0.021 RMSE)
# Test Score: 0.00120 MSE (0.035 RMSE)
# Model: "sequential_96"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_192 (LSTM)              (None, 10, 512)           1052672
# _________________________________________________________________
# dropout_192 (Dropout)        (None, 10, 512)           0
# _________________________________________________________________
# lstm_193 (LSTM)              (None, 512)               2099200
# _________________________________________________________________
# dropout_193 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_192 (Dense)            (None, 64)                32832
# _________________________________________________________________
# dense_193 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 3,184,769
# Trainable params: 3,184,769
# Non-trainable params: 0
# _________________________________________________________________
# 62/62 [==============================] - 8s 129ms/step - loss: 4.5570e-04
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0015
# Train Score: 0.00046 MSE (0.021 RMSE)
# Test Score: 0.00153 MSE (0.039 RMSE)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter([0,0,0,1,1,1,2,2,2,3,3,3,4,4,4], [0,1,2,0,1,2,0,1,2,0,1,2,0,1,2], neurons_result)
ax.xaxis.set_major_locator(plt.LinearLocator(5))
ax.yaxis.set_major_locator(plt.LinearLocator(3)) 
ax.xaxis.set_major_formatter(plt.FixedFormatter(neurons_LSTM))
ax.yaxis.set_major_formatter(plt.FixedFormatter(neurons_Dense))
ax.set_xlabel('LSTM')
ax.set_ylabel('Dense')
# Out:
# C:\Users\Yu\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# C:\Users\Yu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   import sys
# Text(0.5, 0, 'Dense')

# %%
print(pd.DataFrame(data=np.reshape(neurons_result, (5, 3)), index = ['LSTM32', 'LSTM64', 'LSTM128', 'LSTM256', 'LSTM512'], columns=['Dense16', 'Dense32', 'Dense64']))
# Out:
#            Dense16    Dense32    Dense64
# LSTM32   12.882900  13.385602  13.827198
# LSTM64   12.253048  12.905970  13.134951
# LSTM128  14.445460  14.468426  12.914237
# LSTM256  11.963253  12.337801  17.053319
# LSTM512  13.979189  11.884973  13.425141
